# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from joblib import load

# %%
X, y = load('../../preprocesiranje/clustering_data.joblib')

# %%
X.drop(['dislike_hw'], inplace = True, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 X.drop(['dislike_hw'], inplace = True, axis = 1)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
#    5122     labels: IndexLabel = None,
#    (...)
#    5129     errors: IgnoreRaise = "raise",
#    5130 ) -> DataFrame | None:
#    5131     """
#    5132     Drop specified labels from rows or columns.
#    5133
#    (...)
#    5266             weight  1.0     0.8
#    5267     """
# -> 5268     return super().drop(
#    5269         labels=labels,
#    5270         axis=axis,
#    5271         index=index,
#    5272         columns=columns,
#    5273         level=level,
#    5274         inplace=inplace,
#    5275         errors=errors,
#    5276     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:6696, in Index.drop(self, labels, errors)
#    6694 if mask.any():
#    6695     if errors != "ignore":
# -> 6696         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6697     indexer = indexer[~mask]
#    6698 return self.delete(indexer)
#
# KeyError: "['dislike_hw'] not found in axis"

# %% [markdown]
# Podatke za klasterovanje nismo standardizovani tokom preprocesirannje, tako da ćemo prvo izršiti standardizaciju.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(data = X_scaled, columns = X.columns)

# %%
X_scaled.head()
# Out:
#         age    gender  occupation  time_bp   time_dp  travel_time
# 0 -0.924820  0.852431    0.043083 -0.20719 -1.118996    -0.740045  \
# 1 -1.520578  0.852431    0.487135 -0.20719  1.140145    -0.740045
# 2 -0.924820  0.852431    0.043083 -0.20719 -0.365949     0.662459
# 3 -0.924820  0.852431    0.043083 -0.20719 -0.365949     0.662459
# 4 -0.924820 -1.111503    0.043083 -0.20719 -0.365949     0.662459
#
#    easeof_online  home_env  prod_inc  sleep_bal  new_skill  fam_connect
# 0       0.368080  0.200490 -0.014535   0.175435   0.548935     1.077260  \
# 1       1.157303 -0.609048 -0.827779   0.980651  -1.782386     1.077260
# 2      -0.421143 -0.609048  1.611954   0.175435   0.548935     0.348963
# 3       0.368080 -1.418586 -0.014535   1.785868   0.548935    -0.379334
# 4      -0.421143 -0.609048 -0.014535   0.175435  -0.228172    -0.379334
#
#     relaxed  self_time   like_hw    prefer  certaindays_hw
# 0 -0.855317  -1.077189 -1.357072 -0.636791        0.931136
# 1  1.539434   1.694410  0.804100 -0.636791       -0.277797
# 2  0.741184   0.770544  0.780585 -0.636791        0.931136
# 3 -1.653567  -1.077189 -1.357072 -0.636791        0.931136
# 4  0.741184  -0.153322  0.588196 -0.636791        0.931136

# %%
X_scaled.describe()
# Out:
#                 age        gender    occupation       time_bp       time_dp
# count  1.175000e+03  1.175000e+03  1.175000e+03  1.175000e+03  1.175000e+03  \
# mean  -9.675476e-17 -4.837738e-17 -1.148963e-16 -3.023586e-18  1.209434e-17
# std    1.000426e+00  1.000426e+00  1.000426e+00  1.000426e+00  1.000426e+00
# min   -1.520578e+00 -1.111503e+00 -2.177181e+00 -1.703799e+00 -1.495519e+00
# 25%   -9.248197e-01 -1.111503e+00 -8.450227e-01 -1.204929e+00 -1.118996e+00
# 50%   -3.290614e-01  8.524305e-01  4.308255e-02 -2.071901e-01  3.870983e-01
# 75%    8.624552e-01  8.524305e-01  9.311878e-01  7.905491e-01  3.870983e-01
# max    2.053972e+00  2.816364e+00  9.311878e-01  2.287158e+00  1.516669e+00
#
#         travel_time  easeof_online      home_env      prod_inc     sleep_bal
# count  1.175000e+03   1.175000e+03  1.175000e+03  1.175000e+03  1.175000e+03  \
# mean  -7.558965e-17   9.675476e-17  1.814152e-17  9.070758e-18 -3.023586e-18
# std    1.000426e+00   1.000426e+00  1.000426e+00  1.000426e+00  1.000426e+00
# min   -7.400447e-01  -1.210365e+00 -1.418586e+00 -1.641023e+00 -1.434999e+00
# 25%   -7.400447e-01  -1.210365e+00 -6.090480e-01 -8.277790e-01 -6.297825e-01
# 50%   -7.400447e-01  -4.211426e-01  2.004898e-01 -1.453458e-02  1.754345e-01
# 75%    6.624593e-01   1.157303e+00  1.010028e+00  7.987098e-01  9.806515e-01
# max    2.766215e+00   1.946525e+00  1.819565e+00  1.611954e+00  1.785868e+00
#
#           new_skill   fam_connect       relaxed     self_time       like_hw
# count  1.175000e+03  1.175000e+03  1.175000e+03  1.175000e+03  1.175000e+03  \
# mean  -2.872407e-17  4.837738e-17 -2.418869e-17  3.930662e-17  9.070758e-17
# std    1.000426e+00  1.000426e+00  1.000426e+00  1.000426e+00  1.000426e+00
# min   -1.782386e+00 -1.835929e+00 -1.653567e+00 -2.001055e+00 -1.568701e+00
# 25%   -1.005279e+00 -3.793344e-01 -8.553167e-01 -1.077189e+00 -1.357072e+00
# 50%    5.489351e-01  3.489628e-01 -5.706640e-02 -1.533225e-01  5.689572e-01
# 75%    5.489351e-01  1.077260e+00  7.411839e-01  7.705436e-01  7.805853e-01
# max    1.326042e+00  1.077260e+00  1.539434e+00  1.694410e+00  8.040995e-01
#
#              prefer  certaindays_hw
# count  1.175000e+03    1.175000e+03
# mean   1.814152e-17   -1.088491e-16
# std    1.000426e+00    1.000426e+00
# min   -6.367907e-01   -1.486731e+00
# 25%   -6.367907e-01   -1.486731e+00
# 50%   -6.367907e-01   -2.777975e-01
# 75%    1.570375e+00    9.311360e-01
# max    1.570375e+00    9.311360e-01

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 2)

X_pca = pca.fit_transform(X_scaled)

# %% [markdown]
# # K - Means

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
ks = [i for i in range(2, 11)]

fig, axs = plt.subplots(3, 3, figsize = (12, 12))
fig.suptitle("Clustering with different k values")

for k, ax in zip(ks, axs.flatten()):
    kmeans = KMeans(n_clusters = k, n_init = 'auto', random_state = 69)
    kmeans.fit(X_scaled)

    ax.scatter(X_pca[:, 0], X_pca[:, 1], c = kmeans.labels_, cmap = plt.get_cmap("tab10"))
    #ax.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker = 'x', s = 100, color = 'red')
    ax.set_title(f"clusters = {k}")
    ax.set_xlabel("Pc1")
    ax.set_ylabel("Pc2")

plt.tight_layout()
plt.show()

# %%
sse = []
silhouettes = []

for k in ks:
    kmeans = KMeans(n_clusters = k, n_init = 'auto', random_state = 69)
    kmeans.fit(X_pca)

    sse.append(kmeans.inertia_)
    silhouettes.append(silhouette_score(X_pca, kmeans.labels_))


fig, axs = plt.subplots(1, 2, figsize = (12, 5))
fig.suptitle("Optimal cluster count Analysis")


axs[0].plot(ks, sse, marker = 'o')
axs[0].set_xticks(ks)
axs[0].set_xlabel('Number of clusters')
axs[0].set_ylabel('SSE')

axs[1].plot(ks, silhouettes, marker = 'o')
axs[1].set_xlabel('Number of clusters')
axs[1].set_ylabel('Silhouette score')

plt.tight_layout()
plt.show()

# %% [markdown]
# Model sa 4 klastera pruža najbolje rezultate u smislu smanjenja inercije (Sum of Squared Errors) i povećanja vrednosti siluete.

# %% [markdown]
# ### Broj instanci u klasteru

# %%
kmeans = KMeans(n_clusters = 5, n_init = 'auto', random_state = 69)
kmeans.fit(X_scaled)
cluster_sizes = np.bincount(kmeans.labels_)

plt.plot(range(1, 5 + 1), cluster_sizes, marker = 'o', label = f'Clusters = 4')
plt.xlabel('Cluster')
plt.ylabel('Number of Instances')
plt.title('Cluster Sizes')
plt.legend()
plt.show()

for i in range(5):
    print(f'Cluster {i}: {cluster_sizes[i]}')
# Out:
# Cluster 0: 319
# Cluster 1: 231
# Cluster 2: 156
# Cluster 3: 239
# Cluster 4: 230

# %% [markdown]
# ### Karakteristike klastera

# %% [markdown]
# Kategorije kojima su pripali nenumerički atributi:
# * age: 0-18 -> 0, 19-25 -> 1, 26-32 -> 2, 33-40 -> 3, 40-50 -> 4, 50-60 -> 5
# * gender: Female -> 0, Male -> 1, Prefer not to say -> 2
# * occupation: Currently Out of Work -> 0, Entrepreneur -> 1, Homemaker -> 2, Medical Professional aiding efforts against COVID-19 -> 3 Retired/Senior Citizen -> 4, Student in College -> 5, Student in School -> 6,  Working Professional -> 7
# * prefer: Complete Physical Attendance -> 0, Work/study from home -> 1
# * certaindays_hw: Maybe -> 0, No -> 1, Yes -> 2

# %%
kmeans = KMeans(n_clusters = 5, n_init = 'auto', random_state = 69)
kmeans.fit(X_scaled)
cluster_labels = kmeans.predict(X_scaled)  
    
cluster_data = []
cd = []

for i in range(5):
    cd.append(X[cluster_labels == i])
    mean_attributes = np.mean(cd[i], axis = 0)
    cluster_data.append(mean_attributes)
    cd[i] = pd.DataFrame(cd[i], columns = X.columns)
    
# kreiranje DataFrame-a
cluster_df = pd.DataFrame(cluster_data, columns = X.columns)

cluster_df
# Out:
#         age    gender  occupation   time_bp    time_dp  travel_time
# 0  1.119122  0.890282    5.294671  7.147335   6.648903     0.780564  \
# 1  3.406926  0.727273    5.549784  8.064935   7.597403     1.645022
# 2  4.455128  0.217949    2.230769  8.089744  10.275641     0.974359
# 3  2.317992  0.343096    5.025105  6.845188   7.510460     0.893305
# 4  2.634783  0.421739    5.395652  7.269565   9.100000     0.926087
#
#    easeof_online  home_env  prod_inc  sleep_bal  new_skill  fam_connect
# 0       2.369906  3.025078 -0.003135  -0.368339   0.197492     0.257053  \
# 1       2.865801  2.424242 -0.225108   0.415584   0.588745     0.783550
# 2       1.839744  1.794872  0.169872  -0.599359  -0.676282    -0.435897
# 3       1.585774  2.117155  0.566946   0.397490   0.721757     0.769874
# 4       3.882609  4.013043 -0.428261  -0.469565  -0.406522    -0.317391
#
#     relaxed  self_time      like_hw    prefer  certaindays_hw
# 0 -0.083072   0.059561   862.072100  0.097179        1.369906
# 1  0.441558   0.469697   749.822511  0.038961        0.917749
# 2 -0.573718  -0.445513   507.320513  0.371795        0.987179
# 3  0.767782   0.548117  1037.991632  0.966527        1.945607
# 4 -0.554348  -0.397826   382.634783  0.043478        0.769565

# %%
# s obzirom da like_hw i dislike_hw imaju velike vrednosti, nećemo ih predstaviti na grafiku, 
# ali može se zaključiti da oni itekako imaju veliki uticaj (različite vrednosti za klastere)
atr = ['age', 'gender', 'occupation', 'time_bp', 'time_dp', 'travel_time','easeof_online', 'home_env', 
       'prod_inc', 'sleep_bal', 'new_skill', 'fam_connect', 'relaxed', 'self_time', 'prefer', 'certaindays_hw']
plot_df = cluster_df[atr].T


colors = [plt.get_cmap("tab10")(0), plt.get_cmap("tab10")(1), plt.get_cmap("tab10")(2), plt.get_cmap("tab10")(3), plt.get_cmap("tab10")(4)]

# kreiranje grafikona sa grupisanim stubićima
plt.figure(figsize = (12, 8))

bar_width = 0.1  # Širina svake trake
index = np.arange(len(plot_df))  # pozicije za svaku grupu atributa

# prikazivanje grupisanih stubića za svaki atribut i svaku klasu
for i, col in enumerate(plot_df.columns):
    if col != 'like_hw' and col != 'dislike_hw':
        plt.bar(index + i * bar_width, plot_df[col], bar_width, label = f'Cluster {col}')

# postavljanje oznaka na osama
plt.xlabel('Attributes')
plt.ylabel('Attribute values')
plt.legend()

plt.xticks(index + bar_width, plot_df.index, rotation = 45, ha = 'right')
plt.ylim(-1.0, 10.5)

plt.title('Mean attribute values by Cluster')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Histogrami raspodele vrednosti

# %%
plt.figure(figsize = (15, 8))  
for col in cluster_df.columns:  
    plt.subplot(3, 6, cluster_df.columns.get_loc(col) + 1)  
    plt.hist(cd[0][col], bins = 20, alpha = 0.7, color = plt.get_cmap("tab10")(0))
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.suptitle('Cluster 0')
plt.tight_layout()  
plt.show()

# %%
plt.figure(figsize = (15, 8))  
for col in cluster_df.columns:  
    plt.subplot(3, 6, cluster_df.columns.get_loc(col) + 1)  
    plt.hist(cd[1][col], bins = 20, alpha = 0.7, color = plt.get_cmap("tab10")(1))
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.suptitle('Cluster 1')
plt.tight_layout()  
plt.show()

# %%
plt.figure(figsize = (15, 10))  
for col in cluster_df.columns:  
    plt.subplot(3, 6, cluster_df.columns.get_loc(col) + 1)  
    plt.hist(cd[2][col], bins = 20, alpha = 0.7, color = plt.get_cmap("tab10")(2))
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.suptitle('Cluster 2')
plt.tight_layout()  
plt.show()

# %%
plt.figure(figsize = (15, 10))  
for col in cluster_df.columns:  
    plt.subplot(3, 6, cluster_df.columns.get_loc(col) + 1)  
    plt.hist(cd[3][col], bins = 20, alpha = 0.7, color = plt.get_cmap("tab10")(3))
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.suptitle('Cluster 3')
plt.tight_layout()  
plt.show()

# %%
plt.figure(figsize = (15, 10))  
for col in cluster_df.columns:  
    plt.subplot(3, 6, cluster_df.columns.get_loc(col) + 1)  
    plt.hist(cd[4][col], bins = 20, alpha = 0.7, color = plt.get_cmap("tab10")(4))
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.suptitle('Cluster 3')
plt.tight_layout()  
plt.show()

# %% [markdown]
# ## NAPISATI ANALIZU

# %% [markdown]
# Cluster 0:
#
# age: 19-25
# pol: muški
# occupation: studenti i work professional
# produkktivnost: 0
# rešim spavanja: negativan
# veštine ništa spec
# fam connect malo bolje
# relaxed kao pre i negativno
# self time nista
#
#
# Cluster 1:
# age: 50-60
# žene
# raznovrsna zanimanja, najviše domaćice, work profesional, preduyetnice
# radno vreme mnogo povećano
# veštine minus
# fam connect najviše -1
# relaxed -0.5
# self time -0.5
#
#
# Cluster 2:
# age: od 19 do 40
# ugl muškarci
# negativna produktivnost
# poboljšan balans spavanja
# nove veštine
# povezali se s porodicu
# opušteniji
# više vremena za sebe
#
#
# cluster 3:
# age 20te i 40te
# ugl žene
# work professional
# produktivnije
# balans spavanja bolji
# nove veštine
# povezale se s porodice
# opuštenije
# više vremena za sebe
